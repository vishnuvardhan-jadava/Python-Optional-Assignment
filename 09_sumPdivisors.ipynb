# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/09_sumPdivisors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sumPdivisors(n):
  """this function takes an integer as input and returns the sum of all the factors"""
  li=[]
  for i in range(1,n):
    if (n % i) ==0:
      li.append(i)
  #print('divisiors of {} are: {}'.format(n,li))
  return sum(li)

print(sumPdivisors(int(25)))
# Out:
# 6
