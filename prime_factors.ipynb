# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/prime_factors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_prime(n):
    """this function takes a number as input and returns the same number if it is prime"""
    count=0
    for i in range(2,int(n/2)+2):
      if n ==2:
        pass
      elif int(n % i) == 0:
        count+=1
      else:
        pass
    if count>0:
        #print('not_prime')
        pass
    else:
        return n
is_prime(29)
# Out:
# 29

# %%
#print(cc)
def prime_factors(n):
  """this function takes an integer as input and returns the list of prime factors"""
  cc=[]
  for i in range(2,int(n/2)+1):
    if is_prime(i):
      cc.append(i)
  #print('cc is: ',cc)
  fc=[]
  while n>0:
    for i in cc:
      if int(n%i)==0:
        fc.append(i)
        #print('fc is: ',fc)
        break
    n=int(n/i)
    #print('n is: ',n)
  print(fc)
prime_factors(1500)
# Out:
# [2, 2, 3, 5, 5, 5]
