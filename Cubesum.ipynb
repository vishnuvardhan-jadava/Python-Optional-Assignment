# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/Cubesum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #cubesum function: to find the sum of cubes of given number

# %%
def cubesum(n):
    s=0
    while n>1:
        s += (int(n%10)**3)
        n/=10
    return s
print(cubesum(1233))
# Out:
# 63

# %% [markdown]
# #isArmstrong to find whether the given number is an Armstrong number or not

# %%
def isArmstrong(num):
  print('Armstrong') if num == cubesum(num) else print('Not Armstrong')
isArmstrong()
# Out:
# Armstrong

# %%
# Out:
# Armstrong

# %% [markdown]
# #PrintArmstrong. To print Armstrong numbers

# %%
def PrintArmstrong(num):

  """
  This function takes an interger as an input and prints 
  """
  for i in range(1,num+1):
    print(i,' is Armstrong') if i == cubesum(i) else print(i,' is Not Armstrong')
PrintArmstrong(200)
# Out:
# 1  is Not Armstrong
# 2  is Not Armstrong
# 3  is Not Armstrong
# 4  is Not Armstrong
# 5  is Not Armstrong
# 6  is Not Armstrong
# 7  is Not Armstrong
# 8  is Not Armstrong
# 9  is Not Armstrong
# 10  is Not Armstrong
# 11  is Not Armstrong
# 12  is Not Armstrong
# 13  is Not Armstrong
# 14  is Not Armstrong
# 15  is Not Armstrong
# 16  is Not Armstrong
# 17  is Not Armstrong
# 18  is Not Armstrong
# 19  is Not Armstrong
# 20  is Not Armstrong
# 21  is Not Armstrong
# 22  is Not Armstrong
# 23  is Not Armstrong
# 24  is Not Armstrong
# 25  is Not Armstrong
# 26  is Not Armstrong
# 27  is Not Armstrong
# 28  is Not Armstrong
# 29  is Not Armstrong
# 30  is Not Armstrong
# 31  is Not Armstrong
# 32  is Not Armstrong
# 33  is Not Armstrong
# 34  is Not Armstrong
# 35  is Not Armstrong
# 36  is Not Armstrong
# 37  is Not Armstrong
# 38  is Not Armstrong
# 39  is Not Armstrong
# 40  is Not Armstrong
# 41  is Not Armstrong
# 42  is Not Armstrong
# 43  is Not Armstrong
# ...
