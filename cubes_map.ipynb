# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/cubes_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
li = [x for x in range(1,11)]
cubes = list(map(lambda x:x**3,li))
cubes
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]
