# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/perfect_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_perfect(n):
  """this function takes an integer as input and returns if that number is perfect or not"""
  divisors=[]
  for i in range(1,int(n)):
    if (n%i)==0:
      divisors.append(i)
  return 'Perfect' if sum(divisors)==n else 'not-perfect'
print(perfect_number(128))
# Out:
# not-perfect

# %%
def print_perfect(start,end):
  """this function returns all the perfect numbers in a given range"""
  perfect=[]
  for i in range(int(start),int(end)):
    if is_perfect(i) == 'Perfect':
      perfect.append(i)
  print('Perfect numbers between {} and {} is/are: {}'.format(start,end,perfect))
print_perfect(2,1000)
# Out:
# Perfect numbers between 2 and 1000 is/are: [6, 28, 496]
