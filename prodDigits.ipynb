# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/prodDigits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def prodDigits(n):
  """this function takes input as an interger and returns the product of individual digits"""
  s=1
  while n >1:
    s *= int(n%10)
    n/=10
  return s
print(prodDigits(int(12345)))
# Out:
# 120
