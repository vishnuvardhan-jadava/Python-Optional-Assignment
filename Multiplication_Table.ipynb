# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/Multiplication_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input('Enter a number to print Multiplication Table: ')) # taking a number as input from user and convreting it to int
for i in range(1,11):
  print('{} * {} = {}'.format(num,i,num*i))
# Out:
# Enter a number to print Multiplication Table: -3
# -3 * 1 = -3
# -3 * 2 = -6
# -3 * 3 = -9
# -3 * 4 = -12
# -3 * 5 = -15
# -3 * 6 = -18
# -3 * 7 = -21
# -3 * 8 = -24
# -3 * 9 = -27
# -3 * 10 = -30
