# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuvardhan-jadava/Python-Optional-Assignment/blob/master/sumPdivisors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sumPdivisors(n):
  li=[]
  for i in range(1,n):
    if (n % i) ==0:
      li.append(i)
  print('divisiors of {} are: {}'.format(n,li))
  return sum(li)

print(sumPdivisors(int(25)))
# Out:
# divisiors of 25 are: [1, 5]
# 6
